# %%
from usda_requests import *

# %%
response = search_usda('cheese')

# %%
response.json()
# Out:
# {'foodSearchCriteria': {'generalSearchInput': 'cheese',
#   'pageNumber': 1,
#   'requireAllWords': False},
#  'totalHits': 30432,
#  'currentPage': 1,
#  'totalPages': 609,
#  'foods': [{'fdcId': 566821,
#    'description': 'CHEESE',
#    'dataType': 'Branded',
#    'gtinUpc': '070852992686',
#    'publishedDate': '2019-04-01',
#    'brandOwner': 'Clover Stornetta Farms, Inc.',
#    'ingredients': 'CULTURED PASTEURIZED MILK, SALT, NON-ANIMAL ENZYMES, ANNATTO (COLOR), POTATO STARCH, CORN STARCH, POWDERED CELLULOSE (ADDED TO PREVENT CAKING).',
#    'allHighlightFields': '',
#    'score': 228.06624},
#   {'fdcId': 566072,
#    'description': 'CHEESE',
#    'dataType': 'Branded',
#    'gtinUpc': '078742263083',
#    'publishedDate': '2019-04-01',
#    'brandOwner': 'Wal-Mart Stores, Inc.',
# ...

# %%
ingredients = get_ingredients(response)

# %%
ingredients
# Out:
# [['CULTURED PASTEURIZED MILK',
#   ' SALT',
#   ' NON-ANIMAL ENZYMES',
#   ' ANNATTO (COLOR)',
#   ' POTATO STARCH',
#   ' CORN STARCH',
#   ' POWDERED CELLULOSE (ADDED TO PREVENT CAKING).'],
#  ['ENRICHED YELLOW CORN (YELLOW CORN',
#   ' THIAMINE MONONITRATE',
#   ' RIBOFLAVIN',
#   ' NIACIN',
#   ' FERROUS SULFATE',
#   ' FOLIC ACID)',
#   ' VEGETABLE OIL (CONTAINS ONE OR MORE OF THE FOLLOWING: CORN',
#   ' SUNFLOWER',
#   ' OR CANOLA OIL)',
#   ' WHEY',
#   ' SALT',
#   ' COCONUT OIL',
#   ' MALTODEXTRIN',
#   ' MONOSODIUM GLUTAMATE',
#   ' CHEDDAR CHEESE (PASTEURIZED MILK',
#   ' CREAM',
#   ' SALT',
#   ' CULTURES',
#   ' NONFAT MILK',
#   ' ENZYMES)',
#   ' DIPOTASSIUM PHOSPHATE',
#   ' POTASSIUM CHLORIDE',
#   ' NATURAL AND ARTIFICIAL FLAVORS',
#   ' CITRIC ACID',
#   ' LACTIC ACID',
#   ' YELLOW 6',
#   ' YELLOW 5.'],
#  ['PASTEURIZED MILK', ' CHEESE CULTURE', ' SALT', ' ENZYMES.'],
#  ['WATER',
#   ' CORN SYRUP',
# ...

# %%
ingredient_aggregates = ingredient_totals(ingredients)

# %%
ingredient_aggregates
# Out:
# {'CULTURED PASTEURIZED MILK': 10,
#  'SALT': 90,
#  'NON-ANIMAL ENZYMES': 5,
#  'ANNATTO (COLOR': 5,
#  'POTATO STARCH': 7,
#  'CORN STARCH': 6,
#  'POWDERED CELLULOSE (ADDED TO PREVENT CAKING)': 1,
#  'ENRICHED YELLOW CORN (YELLOW CORN': 1,
#  'THIAMINE MONONITRATE': 3,
#  'RIBOFLAVIN': 3,
#  'NIACIN': 3,
#  'FERROUS SULFATE': 3,
#  'FOLIC ACID': 3,
#  'VEGETABLE OIL (CONTAINS ONE OR MORE OF THE FOLLOWING: CORN': 1,
#  'SUNFLOWER': 3,
#  'OR CANOLA OIL': 1,
#  'WHEY': 12,
#  'COCONUT OIL': 1,
#  'MALTODEXTRIN': 3,
#  'MONOSODIUM GLUTAMATE': 2,
#  'CHEDDAR CHEESE (PASTEURIZED MILK': 5,
#  'CREAM': 9,
#  'CULTURES': 22,
#  'NONFAT MILK': 2,
#  'ENZYMES': 51,
#  'DIPOTASSIUM PHOSPHATE': 1,
#  'POTASSIUM CHLORIDE': 1,
#  'NATURAL AND ARTIFICIAL FLAVORS': 2,
#  'CITRIC ACID': 8,
#  'LACTIC ACID': 5,
#  'YELLOW 6': 3,
#  'YELLOW 5': 3,
#  'PASTEURIZED MILK': 39,
#  'CHEESE CULTURE': 35,
#  'WATER': 19,
#  'CORN SYRUP': 4,
#  'CREAM CHEESE (PASTEURIZED CULTURED MILK AND CREAM) SALT': 1,
# ...

# %%
ingredient_frequencies(ingredient_aggregates)
# Out:
# likely ingredients:
# SALT with a confidence of 100.0 %
# MILK with a confidence of 84.44444444444444 %
# CULTURE with a confidence of 67.77777777777779 %
# ENZYME with a confidence of 58.88888888888889 %
# ENZYMES with a confidence of 56.666666666666664 %
# PASTEURIZED MILK with a confidence of 43.333333333333336 %
# CHEESE CULTURE with a confidence of 38.88888888888889 %
# CULTURES with a confidence of 24.444444444444443 %
# WATER with a confidence of 21.11111111111111 %
# CHEESE CULTURES with a confidence of 18.88888888888889 %
# (PASTEURIZED MILK with a confidence of 18.88888888888889 %
# WHEY with a confidence of 13.333333333333334 %
# CULTURED PASTEURIZED MILK with a confidence of 11.11111111111111 %
# CHEDDAR CHEESE with a confidence of 11.11111111111111 %
# CREAM with a confidence of 10.0 %
# VINEGAR with a confidence of 10.0 %
# CITRIC ACID with a confidence of 8.88888888888889 %
# SUGAR with a confidence of 8.88888888888889 %
# ...
